# %%
import pandas as pd

# %%
# 1.Import a 311 NYC service request.

df = pd.read_csv("C:\\Users\\B112-27-IT\\Desktop\\311_Service_Requests_from_2010_to_Present.csv")
# Out:
# D:\sak\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
df.shape
# Out:
# (364558, 53)

# %%
# 2. Read or convert the columns ‘Created Date’ and Closed Date’ to datetime datatype
df['Created Date'] = pd.to_datetime(df['Created Date'])

# %%
df['Closed Date'] = pd.to_datetime(df['Closed Date']) #YYYY-MM-DD

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
df['Request_Closing_Time'] = df['Closed Date']-df['Created Date']

# %%
Request_Closing_Time=[]
for x in (df["Closed Date"]-df["Created Date"]):
    close=x.total_seconds()/60
    Request_Closing_Time.append(close)
    
df["Request_Closing_Time"]=Request_Closing_Time

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
numeric_feature_columns = list(df._get_numeric_data().columns)

# %%
len(numeric_feature_columns)
# Out:
# 12

# %%
numeric_feature_columns
# Out:
# ['Unique Key',
#  'Incident Zip',
#  'X Coordinate (State Plane)',
#  'Y Coordinate (State Plane)',
#  'School or Citywide Complaint',
#  'Vehicle Type',
#  'Taxi Company Borough',
#  'Taxi Pick Up Location',
#  'Garage Lot Name',
#  'Latitude',
#  'Longitude',
#  'Request_Closing_Time']

# %%
#Univariate Distribution Plot for Request Closing Time
y = df['Request_Closing_Time']
plt.figure(figsize = (10,10))
plt.hist(y,bins = 50)
plt.title("Request Closing Time")
plt.show()
# Out:
# D:\sak\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# D:\sak\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
categorical_feature_columns = list(set(df.columns) - set(df._get_numeric_data().columns))
len(categorical_feature_columns)
# Out:
# 42

# %%
categorical_feature_columns
# Out:
# ['Resolution Action Updated Date',
#  'Park Facility Name',
#  'School Not Found',
#  'School City',
#  'Status',
#  'Incident Address',
#  'Park Borough',
#  'Bridge Highway Segment',
#  'Ferry Direction',
#  'Street Name',
#  'Due Date',
#  'Road Ramp',
#  'School Phone Number',
#  'Intersection Street 2',
#  'School State',
#  'School Zip',
#  'Community Board',
#  'Landmark',
#  'Location Type',
#  'Address Type',
#  'Descriptor',
#  'Bridge Highway Direction',
#  'Complaint Type',
#  'Resolution Description',
#  'School Name',
#  'Ferry Terminal Name',
#  'Location',
#  'Created Date',
#  'Cross Street 2',
#  'Cross Street 1',
#  'Bridge Highway Name',
#  'Agency',
#  'Closed Date',
#  'City',
#  'School Code',
#  'School Address',
#  'Facility Type',
#  'School Region',
#  'Intersection Street 1',
#  'Agency Name',
#  'Borough',
#  'School Number']

# %%
import seaborn as sns

# %%
#Checking for Complaint Types that are most frequent
plt.figure(figsize = (10,10))
sns.countplot(y='Complaint Type',data =df)

# %%
# Status of the complaints
plt.figure(figsize = (10,10))
sns.countplot(x='Status',data =df)

# %%
# No. of complaints borough wise

df['Borough'].value_counts()
# Out:
# BROOKLYN         118864
# QUEENS           100766
# MANHATTAN         77462
# BRONX             49169
# STATEN ISLAND     15339
# Unspecified        2958
# Name: Borough, dtype: int64

# %%
#Count Plot for Coloumn Borough
plt.figure(figsize=(12,7))
df['Borough'].value_counts().plot(kind='bar',alpha=0.7)
plt.show()

# %%
import pandas as pd

# %%
#Request Closing Time for all location Type sorted in ascending Order


x = pd.DataFrame(df.groupby("Location Type")["Request_Closing_Time"].mean())
x = x.sort_values("Request_Closing_Time")
x
# Out:
#                             Request_Closing_Time
# Location Type
# Subway Station                        145.120000
# Club/Bar/Restaurant                   183.492218
# House of Worship                      190.052861
# Store/Commercial                      192.928792
# Highway                               204.372348
# Park/Playground                       206.594724
# Bridge                                229.458333
# Street/Sidewalk                       261.052945
# Residential Building                  267.260350
# Commercial                            270.649846
# Roadway Tunnel                        283.486047
# House and Store                       291.750204
# Parking Lot                           296.526747
# Residential Building/House            300.233145
# Vacant Lot                            404.561930
# Park                                20210.566667
# Ferry                                        NaN
# Terminal                                     NaN

# %%
y = pd.crosstab(index = df['Location Type'] , columns = df['Complaint Type'])
y
# Out:
# Complaint Type              Animal Abuse  Animal in a Park  \
# Location Type
# Bridge                                 0                 0
# Club/Bar/Restaurant                    0                 0
# Commercial                           108                 0
# Ferry                                  0                 0
# Highway                                0                 0
# House and Store                      245                 0
# House of Worship                       0                 0
# Park                                   0                 1
# Park/Playground                      144                 0
# Parking Lot                          160                 0
# Residential Building                 533                 0
# Residential Building/House          6727                 0
# Roadway Tunnel                         0                 0
# Store/Commercial                     717                 0
# Street/Sidewalk                     1878                 0
# ...

# %%
y.plot(kind = 'bar',figsize = (10,10),stacked = True)

# %%
#  5: Perform a statistical test for the following:
# Please note: For the below statements you need to state the Null 
# and Alternate and then provide a statistical test to accept or reject the Null Hypothesis along with the corresponding ‘p-value’.
# Whether the average response time across complaint types is similar or not (overall)
# Are the type of complaint or service requested and location related?

# %%
df['Complaint Type'].unique()
# Out:
# array(['Noise - Street/Sidewalk', 'Blocked Driveway', 'Illegal Parking',
#        'Derelict Vehicle', 'Noise - Commercial',
#        'Noise - House of Worship', 'Posting Advertisement',
#        'Noise - Vehicle', 'Animal Abuse', 'Vending', 'Traffic',
#        'Drinking', 'Bike/Roller/Skate Chronic', 'Panhandling',
#        'Noise - Park', 'Homeless Encampment', 'Urinating in Public',
#        'Graffiti', 'Disorderly Youth', 'Illegal Fireworks',
#        'Ferry Complaint', 'Agency Issues', 'Squeegee', 'Animal in a Park'],
#       dtype=object)

# %%
# Since Blocked Driveway is the most frequent complaint I shall analyze that data
df1= df[df['Complaint Type']== 'Blocked Driveway']['Request_Closing_Time']
df1.hist(range=(0,1500)) 
# The data is left skewed, needs to be converted to

# %%
import numpy as np

# %%
# Applying log transformation
dataset={}
for i in df['Complaint Type'].unique():
    dataset[i]= np.log(df[df['Complaint Type']==i]['Request_Closing_Time'])

# %%
dataset['Blocked Driveway'].hist()

# %%
from scipy.stats import f_oneway
stat,p = f_oneway(dataset['Noise - Street/Sidewalk'], dataset['Blocked Driveway'], dataset['Illegal Parking'], dataset['Derelict Vehicle'], 
                dataset['Noise - Commercial'])

alpha=0.05
if p>0.05:
    print('Null Hypothesis is accepted')
else:
    print('Null hypothesis is rejected')
# Out:
# Null hypothesis is rejected

# %%
# 2.Are the type of complaint or service requested and location related?
df3= df[['Complaint Type','Location','Latitude','Longitude','City','Borough']]

# %%
df3.head()
# Out:
#             Complaint Type                                  Location  \
# 0  Noise - Street/Sidewalk   (40.86568153633767, -73.92350095571744)
# 1         Blocked Driveway  (40.775945312321085, -73.91509393898605)
# 2         Blocked Driveway  (40.870324522111424, -73.88852464418646)
# 3          Illegal Parking   (40.83599404683083, -73.82837939584206)
# 4          Illegal Parking  (40.733059618956815, -73.87416975810375)
#
#     Latitude  Longitude      City    Borough
# 0  40.865682 -73.923501  NEW YORK  MANHATTAN
# 1  40.775945 -73.915094   ASTORIA     QUEENS
# 2  40.870325 -73.888525     BRONX      BRONX
# 3  40.835994 -73.828379     BRONX      BRONX
# 4  40.733060 -73.874170  ELMHURST     QUEENS

# %%
df3['Complaint Type']=df3['Complaint Type'].astype('category').cat.codes
df3['City']= df3['City'].astype('category').cat.codes
df3['Borough']= df3['Borough'].astype('category').cat.codes
# Out:
# D:\sak\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# D:\sak\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\sak\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df3.head()
# Out:
#    Complaint Type                                  Location   Latitude  \
# 0              16   (40.86568153633767, -73.92350095571744)  40.865682
# 1               4  (40.775945312321085, -73.91509393898605)  40.775945
# 2               4  (40.870324522111424, -73.88852464418646)  40.870325
# 3              12   (40.83599404683083, -73.82837939584206)  40.835994
# 4              12  (40.733059618956815, -73.87416975810375)  40.733060
#
#    Longitude  City  Borough
# 0 -73.923501    33        2
# 1 -73.915094     1        3
# 2 -73.888525     6        0
# 3 -73.828379     6        0
# 4 -73.874170    13        3

# %%
df3.corr(method='pearson') # From the first line it can be seen that the complaint types does not depend upon the location
# Out:
#                 Complaint Type  Latitude  Longitude      City   Borough
# Complaint Type        1.000000  0.135823  -0.188861  0.098601 -0.048091
# Latitude              0.135823  1.000000   0.374057 -0.010133 -0.249661
# Longitude            -0.188861  0.374057   1.000000 -0.125632  0.020732
# City                  0.098601 -0.010133  -0.125632  1.000000  0.655557
# Borough              -0.048091 -0.249661   0.020732  0.655557  1.000000
